# %%
from pyspark.sql import SparkSession
spark = SparkSession\
.builder\
.appName("Python Spark SQL")\
.config("spark.some.config.option", "some-value")\
.getOrCreate()

sc = spark.sparkContext

# %%
# !ls -l ../Data
# !pwd

# %%
lines=sc.textFile("DigitalBreathTestData2013.txt")

lines.collect()
# Out:
# ['Reason,Month,Year,WeekType,TimeBand,BreathAlcoholLevel(microg 100ml),AgeBand,Gender',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,80,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,96,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,45,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,60,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,110,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,46,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,25-29,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,33,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,83,20-24,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4pm-8pm,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,66,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,19,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,48,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,60-69,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,25-29,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,55,16-19,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,15,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,23,30-39,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,50-59,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,16-19,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,40-49,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,7,60-69,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Other,Jan,2013,Weekday,12pm-4pm,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Other,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,70-98,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Female',
#  'Other,Jan,2013,Weekday,12pm-4pm,0,50-59,Male',
#  'Other,Jan,2013,Weekday,12am-4am,36,70-98,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,90,20-24,Male',
#  'Other,Jan,2013,Weekday,4am-8am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,25-29,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,60-69,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,30-39,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,60-69,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,30-39,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,5,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,33,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,154,25-29,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,40-49,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,0,25-29,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,14,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,95,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,42,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,50-59,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,70-98,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,57,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,15,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,47,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,66,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,100,25-29,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,35,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4pm-8pm,78,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,50-59,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,89,40-49,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,30-39,Male',
#  'Other,Jan,2013,Weekday,8pm-12pm,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,46,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,24,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,5,25-29,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,85,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,0,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,70-98,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,3,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,92,20-24,Female',
#  'Other,Jan,2013,Weekday,8am-12pm,0,20-24,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,16-19,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,25-29,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,16-19,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,63,Other,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,11,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,30-39,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,25-29,Male',
#  'Other,Jan,2013,Weekday,12pm-4pm,55,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,55,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,40-49,Male',
#  'Other,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Other,Jan,2013,Weekday,8pm-12pm,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,82,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,70-98,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,60-69,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4pm-8pm,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,60-69,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,60-69,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,51,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,28,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,70-98,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,67,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12pm-4pm,0,50-59,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,70-98,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,55,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,16-19,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,68,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,78,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,18,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,25-29,Male',
#  'Other,Jan,2013,Weekday,12am-4am,0,40-49,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,18,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,16,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,106,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,44,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,20-24,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,105,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,70-98,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,3,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,60-69,Female',
#  'Other,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,30-39,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Other,Jan,2013,Weekday,4pm-8pm,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,60-69,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,10,50-59,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Other,Jan,2013,Weekday,4am-8am,0,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Other,Jan,2013,Weekday,4am-8am,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,0,25-29,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,50-59,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,33,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,57,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,64,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,112,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,91,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,118,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,60-69,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,27,16-19,Female',
#  'Other,Jan,2013,Weekday,8am-12pm,62,25-29,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,69,20-24,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,37,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,16-19,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,94,Other,Male',
#  'Other,Jan,2013,Weekday,4am-8am,89,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,16,16-19,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,30-39,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,50-59,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,0,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,60-69,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,35,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Other,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,54,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,50-59,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,25-29,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,9,25-29,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,40-49,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,60-69,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,60-69,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,60-69,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,30-39,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,132,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,48,16-19,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,0,40-49,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,60-69,Female',
#  'Other,Jan,2013,Weekday,8am-12pm,0,60-69,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,50-59,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,40-49,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,132,50-59,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,60-69,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,53,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,0,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,25-29,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,50-59,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Other,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Other,Jan,2013,Weekday,12pm-4pm,29,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,66,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,60-69,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,0,60-69,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,30-39,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,56,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,4,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,46,25-29,Male',
#  'Other,Jan,2013,Weekday,4am-8am,36,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,107,Other,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,84,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,4,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,17,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,93,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,64,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,67,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,60-69,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,9,Other,Female',
#  'Other,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,40-49,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,15,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,25-29,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,16-19,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,50-59,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,60-69,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,0,25-29,Male',
#  'Other,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,33,30-39,Female',
#  'Other,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,70-98,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,9,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,16-19,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,65,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,72,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,94,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12pm-4pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,50-59,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Other,Jan,2013,Weekday,4am-8am,75,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,10,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,20-24,Female',
#  'Other,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,27,50-59,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,23,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Other,Jan,2013,Weekday,12am-4am,9,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12pm-4pm,16,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,30-39,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,63,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,87,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,60-69,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,45,16-19,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,52,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,70-98,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,25-29,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,16-19,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,30,50-59,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,34,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,60-69,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Female',
#  'Other,Jan,2013,Weekday,8am-12pm,0,70-98,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,50-59,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,35,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,88,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Other,Jan,2013,Weekday,12pm-4pm,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,22,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,16-19,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,72,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,3,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,30-39,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,60-69,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,70-98,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,0,16-19,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12pm-4pm,3,70-98,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,121,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,0,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,4,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,60-69,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4pm-8pm,0,30-39,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,60-69,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,61,60-69,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,20-24,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,65,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,16-19,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,7,50-59,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4pm-8pm,0,60-69,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,30-39,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,60-69,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,20-24,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,Other,Female',
#  'Other,Jan,2013,Weekday,8am-12pm,0,60-69,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,0,16-19,Male',
#  'Other,Jan,2013,Weekday,12pm-4pm,0,30-39,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,15,40-49,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,20-24,Male',
#  'Other,Jan,2013,Weekday,4am-8am,44,16-19,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,9,70-98,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,50-59,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,32,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,118,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,30-39,Male',
#  'Other,Jan,2013,Weekday,4am-8am,0,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,13,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,14,70-98,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,68,25-29,Male',
#  'Other,Jan,2013,Weekday,12pm-4pm,14,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,33,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4pm-8pm,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Other,Jan,2013,Weekday,4am-8am,11,30-39,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,83,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,40-49,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,25,50-59,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,69,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,20-24,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,30,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,47,40-49,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,124,25-29,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4pm-8pm,0,30-39,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,8,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,57,30-39,Male',
#  'Other,Jan,2013,Weekday,12am-4am,83,50-59,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,34,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,106,40-49,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12pm-4pm,0,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,20-24,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,60-69,Female',
#  'Other,Jan,2013,Weekday,4pm-8pm,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,4,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Other,Jan,2013,Weekday,8pm-12pm,0,60-69,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,176,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,3,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,16-19,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Other,Jan,2013,Weekday,4am-8am,0,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,30-39,Female',
#  'Other,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,31,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,30-39,Male',
#  'Other,Jan,2013,Weekday,12pm-4pm,0,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,Other,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,16-19,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,76,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,46,25-29,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,60-69,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,88,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,95,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,40-49,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,16-19,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,30-39,Female',
#  'Other,Jan,2013,Weekday,4pm-8pm,107,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,25-29,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,40-49,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,30-39,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4pm-8pm,0,50-59,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,116,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,94,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,81,Other,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,52,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,70-98,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,57,20-24,Male',
#  'Other,Jan,2013,Weekday,12pm-4pm,0,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,41,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,22,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,12,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,33,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,59,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,195,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,66,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekend,8am-12pm,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,38,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,60-69,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,25,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,37,60-69,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,44,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,50-59,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,51,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,35,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Female',
#  'Other,Jan,2013,Weekday,12am-4am,56,20-24,Male',
#  'Other,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,78,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,30-39,Female',
#  'Other,Jan,2013,Weekday,8am-12pm,5,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,19,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,60,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,101,30-39,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4pm-8pm,0,30-39,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12pm-4pm,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,0,70-98,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,9,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,3,70-98,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,170,30-39,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,25-29,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,38,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,65,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,69,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,64,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,50-59,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,46,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,21,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,60-69,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,7,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,40,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,21,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,42,40-49,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,16-19,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,0,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,81,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,16-19,Male',
#  'Other,Jan,2013,Weekday,12am-4am,155,40-49,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,50-59,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,60-69,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,50-59,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,12,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Other,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,32,60-69,Male',
#  'Other,Jan,2013,Weekday,12am-4am,54,25-29,Female',
#  'Other,Jan,2013,Weekday,12am-4am,47,20-24,Female',
#  'Other,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,70-98,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,60-69,Male',
#  'Other,Jan,2013,Weekday,12am-4am,44,30-39,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,11,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Other,Jan,2013,Weekday,12pm-4pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,73,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,46,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,60-69,Female',
#  'Other,Jan,2013,Weekday,12am-4am,24,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Female',
#  'Other,Jan,2013,Weekday,12pm-4pm,54,20-24,Female',
#  'Other,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,0,25-29,Male',
# ...
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,60-69,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,50-59,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,70-98,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,5,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,50-59,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,0,70-98,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,25-29,Male',
#  'Other,Jan,2013,Weekday,4am-8am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,37,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,14,25-29,Male',
#  'Other,Jan,2013,Weekday,12pm-4pm,21,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,60-69,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4pm-8pm,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,60-69,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,0,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,30-39,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,52,50-59,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,30-39,Female',
#  'Other,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,50-59,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,40-49,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,25-29,Male',
#  'Other,Jan,2013,Weekday,4am-8am,75,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,25-29,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,40,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,30,Other,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,29,Other,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,12,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,60-69,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,70-98,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,0,20-24,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,34,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,40-49,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,39,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,25-29,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,18,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,26,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,50-59,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,20-24,Female',
#  'Other,Jan,2013,Weekday,12am-4am,34,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,20-24,Male',
#  'Other,Jan,2013,Weekday,4pm-8pm,8,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,19,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,71,70-98,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,69,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,95,30-39,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,46,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,0,20-24,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,0,40-49,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,16-19,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,60-69,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,25-29,Male',
#  'Other,Jan,2013,Weekday,8pm-12pm,0,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,35,40-49,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,40-49,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,60-69,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,40,16-19,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,13,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,25-29,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4pm-8pm,2,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,40-49,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekend,8pm-12pm,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekend,8pm-12pm,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,16,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,100,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Other,Jan,2013,Weekday,4am-8am,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,19,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,60-69,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,69,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,25-29,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,77,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,16,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,71,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,14,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,70-98,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,25-29,Male',
#  'Other,Jan,2013,Weekday,12pm-4pm,0,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,20-24,Male',
#  'Other,Jan,2013,Weekday,4am-8am,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,40-49,Female',
#  'Other,Jan,2013,Weekday,8am-12pm,0,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,25-29,Female',
#  'Other,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,0,40-49,Female',
#  'Other,Jan,2013,Weekday,4pm-8pm,0,50-59,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,26,Other,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,25-29,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,54,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,70-98,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,60-69,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4am-8am,0,16-19,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,65,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,50-59,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,5,60-69,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,60-69,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,85,25-29,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,59,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,60-69,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,111,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,0,70-98,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8am-12pm,112,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,92,20-24,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,40-49,Female',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,122,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,16-19,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,20-24,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,19,Other,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4pm-8pm,44,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,40-49,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8am-12pm,0,70-98,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12pm-4pm,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,62,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Other,Jan,2013,Weekday,12am-4am,0,20-24,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12pm-4pm,0,70-98,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,112,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,61,16-19,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,6,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,4am-8am,20,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,50-59,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,0,Other,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8am-12pm,0,25-29,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12pm-4pm,0,50-59,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,12am-4am,37,25-29,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,8pm-12pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Female',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,110,20-24,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,8pm-12pm,6,30-39,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,30-39,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,30-39,Male',
#  'Other,Jan,2013,Weekday,8am-12pm,0,40-49,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,60-69,Female',
#  'Moving Traffic Violation,Jan,2013,Weekday,4pm-8pm,0,50-59,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,8pm-12pm,0,30-39,Male',
#  'Suspicion of Alcohol,Jan,2013,Weekday,12am-4am,0,16-19,Male',
#  'Road Traffic Collision,Jan,2013,Weekday,4am-8am,74,20-24,Male',
#  'Moving Traffic Violation,Jan,2013,Weekday,12am-4am,0,20-24,Male',
#  'Other,Jan,2013,Weekday,4am-8am,0,20-24,Male',
#  ...]

# %%
header = lines.first()
justdata = lines.filter(lambda row: row != header)

# %%
def parseline(line):
    fields = line.split(',')
    Reason = fields[0]
    return (Reason, 1)

# %%
#Apply the parseline function to lines
allreasons = lines.map(parseline)

# %%
allreasons.count()
# Out:
# 497791

# %%
#Count the different reason types -- just output the value.
allreasons.countByKey()
# Out:
# defaultdict(int,
#             {'Reason': 1,
#              'Moving Traffic Violation': 179064,
#              'Road Traffic Collision': 168526,
#              'Suspicion of Alcohol': 94685,
#              'Other': 55372,
#              'Unknown': 143})

# %%
def parseline2(line):
    fields = line.split(',')
    Reason = fields[0]
    Month = fields[1]
    Year = fields[2]
    WeekType = fields[3]
    TimeBand = fields[4]
    BreathAlcoholLevel = int(fields[5])
    AgeBand = fields[6]
    if fields[7]=='Female':
        Gender = 2
    else:
        Gender = 1
    return (Reason,Month,Year,WeekType,TimeBand,BreathAlcoholLevel,AgeBand,Gender)

# %%
header = lines.first() #extract header
justdata = lines.filter(lambda row: row != header)   #filter out header
rdd = justdata.map(parseline2) # split lines into colimnd

rdd.count()
# Out:
# 497790

# %%
df = spark.createDataFrame(rdd, header.split(','))

# %%
df.show()
# Out:
# +--------------------+-----+----+--------+--------+--------------------------------+-------+------+
# |              Reason|Month|Year|WeekType|TimeBand|BreathAlcoholLevel(microg 100ml)|AgeBand|Gender|
# +--------------------+-----+----+--------+--------+--------------------------------+-------+------+
# |Moving Traffic Vi...|  Jan|2013| Weekday|12am-4am|                              80|  30-39|     1|
# |Road Traffic Coll...|  Jan|2013| Weekday|12am-4am|                               0|  Other|     1|
# |Road Traffic Coll...|  Jan|2013| Weekday|12am-4am|                              96|  Other|     1|
# |Moving Traffic Vi...|  Jan|2013| Weekday|12am-4am|                               0|  40-49|     2|
# |Suspicion of Alcohol|  Jan|2013| Weekday|12am-4am|                               0|  40-49|     1|
# |Road Traffic Coll...|  Jan|2013| Weekday|8am-12pm|                              45|  Other|     1|
# |Moving Traffic Vi...|  Jan|2013| Weekday|12am-4am|                              60|  30-39|     1|
# |Moving Traffic Vi...|  Jan|2013| Weekday|12am-4am|                               0|  16-19|     1|
# |Moving Traffic Vi...|  Jan|2013| Weekday|12am-4am|                               0|  16-19|     1|
# |Moving Traffic Vi...|  Jan|2013| Weekday|8am-12pm|                               0|  50-59|     1|
# |Moving Traffic Vi...|  Jan|2013| Weekday|8pm-12pm|                               0|  30-39|     1|
# |Suspicion of Alcohol|  Jan|2013| Weekday|12am-4am|                             110|  30-39|     1|
# |Suspicion of Alcohol|  Jan|2013| Weekday|12am-4am|                              46|  16-19|     1|
# |Road Traffic Coll...|  Jan|2013| Weekday| 4am-8am|                               0|  Other|     1|
# |Moving Traffic Vi...|  Jan|2013| Weekday| 4pm-8pm|                               0|  25-29|     2|
# |Moving Traffic Vi...|  Jan|2013| Weekday| 4pm-8pm|                               0|  30-39|     1|
# |Road Traffic Coll...|  Jan|2013| Weekday|8am-12pm|                              33|  Other|     1|
# |Road Traffic Coll...|  Jan|2013| Weekday| 4am-8am|                              83|  20-24|     1|
# |               Other|  Jan|2013| Weekday|8am-12pm|                               0|  30-39|     1|
# |Suspicion of Alcohol|  Jan|2013| Weekday| 4pm-8pm|                               0|  Other|     1|
# +--------------------+-----+----+--------+--------+--------------------------------+-------+------+
# only showing top 20 rows

# %%
df.printSchema()
# Out:
# root
#  |-- Reason: string (nullable = true)
#  |-- Month: string (nullable = true)
#  |-- Year: string (nullable = true)
#  |-- WeekType: string (nullable = true)
#  |-- TimeBand: string (nullable = true)
#  |-- BreathAlcoholLevel(microg 100ml): long (nullable = true)
#  |-- AgeBand: string (nullable = true)
#  |-- Gender: long (nullable = true)

# %%
from pyspark.sql.types import *
myschema = StructType(
    [StructField("Reason",StringType(),True),
     StructField("Month",StringType(),True),
     StructField("Year",IntegerType(),True),
     StructField("WeekType",StringType(),True),
     StructField("TimeBand",StringType(),True),
     StructField("AlcoholLevel",IntegerType(),True),
     StructField("AgeBand",StringType(),True),
     StructField("Gender",StringType(),True)])

# %%
df.show()
# Out:
# +--------------------+-----+----+--------+--------+--------------------------------+-------+------+
# |              Reason|Month|Year|WeekType|TimeBand|BreathAlcoholLevel(microg 100ml)|AgeBand|Gender|
# +--------------------+-----+----+--------+--------+--------------------------------+-------+------+
# |Moving Traffic Vi...|  Jan|2013| Weekday|12am-4am|                              80|  30-39|     1|
# |Road Traffic Coll...|  Jan|2013| Weekday|12am-4am|                               0|  Other|     1|
# |Road Traffic Coll...|  Jan|2013| Weekday|12am-4am|                              96|  Other|     1|
# |Moving Traffic Vi...|  Jan|2013| Weekday|12am-4am|                               0|  40-49|     2|
# |Suspicion of Alcohol|  Jan|2013| Weekday|12am-4am|                               0|  40-49|     1|
# |Road Traffic Coll...|  Jan|2013| Weekday|8am-12pm|                              45|  Other|     1|
# |Moving Traffic Vi...|  Jan|2013| Weekday|12am-4am|                              60|  30-39|     1|
# |Moving Traffic Vi...|  Jan|2013| Weekday|12am-4am|                               0|  16-19|     1|
# |Moving Traffic Vi...|  Jan|2013| Weekday|12am-4am|                               0|  16-19|     1|
# |Moving Traffic Vi...|  Jan|2013| Weekday|8am-12pm|                               0|  50-59|     1|
# |Moving Traffic Vi...|  Jan|2013| Weekday|8pm-12pm|                               0|  30-39|     1|
# |Suspicion of Alcohol|  Jan|2013| Weekday|12am-4am|                             110|  30-39|     1|
# |Suspicion of Alcohol|  Jan|2013| Weekday|12am-4am|                              46|  16-19|     1|
# |Road Traffic Coll...|  Jan|2013| Weekday| 4am-8am|                               0|  Other|     1|
# |Moving Traffic Vi...|  Jan|2013| Weekday| 4pm-8pm|                               0|  25-29|     2|
# |Moving Traffic Vi...|  Jan|2013| Weekday| 4pm-8pm|                               0|  30-39|     1|
# |Road Traffic Coll...|  Jan|2013| Weekday|8am-12pm|                              33|  Other|     1|
# |Road Traffic Coll...|  Jan|2013| Weekday| 4am-8am|                              83|  20-24|     1|
# |               Other|  Jan|2013| Weekday|8am-12pm|                               0|  30-39|     1|
# |Suspicion of Alcohol|  Jan|2013| Weekday| 4pm-8pm|                               0|  Other|     1|
# +--------------------+-----+----+--------+--------+--------------------------------+-------+------+
# only showing top 20 rows

# %%
df.schema
# Out:
# StructType([StructField('Reason', StringType(), True), StructField('Month', StringType(), True), StructField('Year', StringType(), True), StructField('WeekType', StringType(), True), StructField('TimeBand', StringType(), True), StructField('BreathAlcoholLevel(microg 100ml)', LongType(), True), StructField('AgeBand', StringType(), True), StructField('Gender', LongType(), True)])
